# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
from sklearn.datasets import fetch_california_housing 
boston=fetch_california_housing()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(boston.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(boston.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(boston.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(boston.frame)
# Out:
# None

# %%
dataset0=pd.DataFrame(boston.data)

# %%
dataset0.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
dataset=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset['price']=boston.target
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64

# %%
###correlation for linear regression
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.scatter(dataset['MedInc'],dataset['price'])
plt.xlabel('median income')
plt.ylabel('price')
plt.show()

# %%
plt.scatter(dataset['HouseAge'],dataset['price'])
plt.xlabel('HouseAge')
plt.ylabel('price')
plt.show()

# %%
plt.scatter(dataset['AveRooms'],dataset['price'])
plt.xlabel('AveRooms')
plt.ylabel('price')
plt.show()

# %%
import seaborn as sns
sns.regplot(x='Latitude',y='price',data=dataset)
plt.show()

# %%
x=dataset.iloc[:,:-1]   ## all features except for the last price
y=dataset.iloc[:,-1]      ## take the dependent data feature (price)

# %%
x.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=34)

# %%
x_train
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 11928   4.0966      20.0  5.780069   1.017182       706.0  2.426117     33.94
# 8038    7.6526      29.0  7.014327   1.014327       894.0  2.561605     33.84
# 13737   6.2917      14.0  7.310263   1.016706      1570.0  3.747017     34.04
# 8001    3.5500      36.0  4.654321   0.965432      1049.0  2.590123     33.85
# 60      3.3929      52.0  5.994652   1.128342       554.0  2.962567     37.83
# ...        ...       ...       ...        ...         ...       ...       ...
# 16708   4.0403      16.0  6.438813   1.133498      2284.0  2.823239     35.18
# 3157    2.7845      28.0  5.108262   1.019943      1233.0  3.512821     35.30
# 10730   5.1155      35.0  3.888078   0.968370       782.0  1.902676     33.60
# 5242   15.0001      32.0  8.002869   1.080344      1567.0  2.248207     34.11
# 11681   2.8169      29.0  4.266559   1.029079      2413.0  3.898223     33.84
#
#        Longitude
# ...

# %%
x_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 6658   3.0119      22.0  3.772009   1.083521      1005.0  2.268623     34.15
# 2118   3.9514      27.0  5.017804   0.836795       869.0  2.578635     36.75
# 12101  5.5563      13.0  6.726190   1.016156      3382.0  2.875850     33.94
# 4076   7.9625      33.0  6.520599   1.026217       588.0  2.202247     34.14
# 15872  3.0774      52.0  4.997984   1.038306      1816.0  3.661290     37.76
# ...       ...       ...       ...        ...         ...       ...       ...
# 8497   3.5417      38.0  3.456790   0.985185      1131.0  2.792593     33.90
# 1708   4.3958      38.0  5.656250   1.049479       945.0  2.460938     37.94
# 8017   4.5417      36.0  6.203187   1.075697       697.0  2.776892     33.84
# 16332  4.4063      20.0  5.900560   1.051821      2071.0  2.900560     38.03
# 16189  1.2962      52.0  3.659091   1.090909      1025.0  2.329545     37.97
#
#        Longitude
# 6658     -118.12
# ...

# %%
## standerdize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
x_test=scaler.transform(x_test)
# Out:
# C:\Users\dhanu\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
x_train
# Out:
# array([[ 0.12004525, -0.68573419,  0.12811849, ..., -0.08868281,
#         -0.79283447,  1.10428421],
#        [ 1.99537045,  0.02901726,  0.59383867, ..., -0.06886675,
#         -0.83950431,  0.7141955 ],
#        [ 1.27767358, -1.16223516,  0.7055036 , ...,  0.10450834,
#         -0.74616464,  1.1843024 ],
#        ...,
#        [ 0.65738182,  0.50551823, -0.58578282, ..., -0.16523975,
#         -0.95151191,  0.85422734],
#        [ 5.87021631,  0.26726775,  0.96684364, ..., -0.11470346,
#         -0.71349576,  0.58916706],
#        [-0.55482923,  0.02901726, -0.44297127, ...,  0.12662334,
#         -0.83950431,  0.78921256]], shape=(14448, 8))

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
### print the coefficients  and intercept
print(regression.coef_)
# Out:
# [ 0.81736685  0.11825757 -0.26308479  0.30542772 -0.00098399 -0.02882316
#  -0.89974583 -0.86503504]

# %%
print(regression.intercept_)
# Out:
# 2.069245688676637

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
## prediticion with test data
reg_pred=regression.predict(x_test)

# %%
print(reg_pred)
# Out:
# [1.7916117  1.57394826 2.21707548 ... 2.45622246 1.90411878 1.11641945]

# %%
## scatter plot
plt.scatter(y_test,reg_pred)

# %%
plt.show()

# %%
## errors
residual=y_test-reg_pred

# %%
residual
# Out:
# 6658    -0.077612
# 2118    -0.704948
# 12101   -0.072075
# 4076     1.038063
# 15872    0.713239
#            ...
# 8497    -0.344542
# 1708    -0.609782
# 8017    -0.260222
# 16332   -0.596119
# 16189   -0.014419
# Name: price, Length: 6192, dtype: float64

# %%
## plot this residuals
sns.displot(residual,kind='kde')
plt.show()

# %%
### scatter plot with respect to  prediction and residuals
plt.scatter(reg_pred,residual)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
# Out:
# 0.5302435829258558
# 0.5123546186838853

# %%
### R square and adjusted R
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.6182480034321205

# %%
###adjusted R2=1-[(1-R2)*(n-1)/(n-k-1)]
n = len(y_test)
p = x_test.shape[1]
1 - (1 - score) * (n - 1) / (n - p - 1)
# Out:
# 0.6177540658658027

# %%
###data prediction
boston.data[0].shape
# Out:
# (8,)

# %%
boston.data[0].reshape(1,-1).shape
# Out:
# (1, 8)

# %%
### standardization
pre=scaler.transform(boston.data[0].reshape(1,-1))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
regression.predict(pre)
# Out:
# array([4.11755104])

# %%
###pickling the model file for deployment
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(pre)
# Out:
# array([4.11755104])
